# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('Dados/aluguel_uma_variavel_com_ruido.csv')
df['Preco'] = df['Preco'].round()
print(df)
# Out:
#      Area   Preco
# 0     132  3464.0
# 1     136  3327.0
# 2     101  2826.0
# 3     218  5284.0
# 4      50  2163.0
# ..    ...     ...
# 495   178  4809.0
# 496   109  2827.0
# 497   242  5543.0
# 498   232  5511.0
# 499   281  6504.0
#
# [500 rows x 2 columns]

# %%
plt.scatter(df['Area'], df['Preco'])
plt.xlabel('Área (m²)')
plt.ylabel('Preço do Aluguel (R$)')
plt.title('Preço do Aluguel x Área da Casa')
plt.show()

# %%
X = df[['Area']]
y = df['Preco']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
modelo = LinearRegression()
modelo.fit(X_train, y_train)
y_pred = modelo.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='aquamarine', label='Dados de Teste')
plt.plot(X_test, y_pred, color='darkviolet', linewidth=2, label='Regressão Linear')
plt.xlabel('Área (m²)')
plt.ylabel('Preço do Aluguel (R$)')
plt.title('Regressão Linear: Preço do Aluguel x Área da Casa')
plt.legend()
plt.show()

# %%
print(f"R²: {r2_score(y_test, y_pred):.2f}")
# Out:
# R²: 0.97
